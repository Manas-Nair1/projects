# %%
import pandas as pd
import yfinance as yf
import datetime
import backtrader as bt

# %%
cerebro = bt.Cerebro()
start_portfolio_value = cerebro.broker.getvalue()
print(f"start portfolio value: {start_portfolio_value}")


df_btc = yf.download("BTC",start= "2022-01-01", end="2023-01-01")
df_eth = yf.download("ETH-USD",start= "2022-01-01", end="2023-01-01" )
print(df_btc)
print(df_eth)
# Out:
# start portfolio value: 10000.0
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2022-01-03  98.309998  98.309998  98.294701  98.294701  95.546432     177
# 2022-01-04  98.279999  98.291496  98.279999  98.291496  95.543312  356148
# 2022-01-05  98.250000  98.269997  98.090103  98.096397  95.353676  356863
# 2022-01-06  97.985001  97.985001  97.985001  97.985001  95.245377     104
# 2022-01-07  97.894600  97.894600  97.894600  97.894600  95.157509       3
# ...               ...        ...        ...        ...        ...     ...
# 2022-12-23  90.771004  90.804497  90.760002  90.804497  89.343491    1308
# 2022-12-27  90.509598  90.509598  90.509598  90.509598  89.053345      15
# 2022-12-28  90.420998  90.434700  90.420998  90.434700  88.979645     168
# 2022-12-29  90.592300  90.592300  90.592300  90.592300  89.134712      84
# 2022-12-30  90.431702  90.431702  90.431702  90.431702  88.976692      33
#
# [251 rows x 6 columns]
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-01  3683.047119  3769.917969  3682.286621  3769.697021  3769.697021
# 2022-01-02  3769.298340  3836.161865  3727.357422  3829.564941  3829.564941
# 2022-01-03  3829.535645  3836.198730  3698.047607  3761.380371  3761.380371
# 2022-01-04  3761.361572  3876.785156  3723.349854  3794.056641  3794.056641
# 2022-01-05  3794.269043  3842.059814  3456.745361  3550.386963  3550.386963
# ...                 ...          ...          ...          ...          ...
# 2022-12-27  1226.987061  1230.418091  1205.895630  1212.791626  1212.791626
# 2022-12-28  1212.736572  1213.128906  1185.702148  1189.986084  1189.986084
# 2022-12-29  1190.010132  1204.141602  1188.360229  1201.595337  1201.595337
# 2022-12-30  1201.569580  1202.034668  1187.462524  1199.232788  1199.232788
# 2022-12-31  1199.360107  1205.088623  1194.203735  1196.771240  1196.771240
#
#                  Volume
# Date
# 2022-01-01   9776191466
# 2022-01-02   9881471548
# 2022-01-03  12080777893
# 2022-01-04  14030925983
# 2022-01-05  18061338502
# ...                 ...
# 2022-12-27   4091530737
# 2022-12-28   4991669631
# 2022-12-29   4132233940
# 2022-12-30   4055668253
# 2022-12-31   3018513333
#
# [365 rows x 6 columns]

# %%
df_signals = pd.read_csv("/workspaces/projects/Backtesting/signals.csv")
new_df = df_signals.set_index('timestamp')['signal'].to_frame()
new_df.index = pd.to_datetime(new_df.index)
print(new_df.tail())
print(new_df.info())
# Out:
#                        signal
# timestamp
# 2022-12-30 08:00:00 -0.253285
# 2022-12-30 16:00:00 -0.145851
# 2022-12-31 00:00:00 -0.140179
# 2022-12-31 08:00:00  0.142683
# 2022-12-31 16:00:00  0.339424
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1095 entries, 2022-01-01 00:00:00 to 2022-12-31 16:00:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   signal  1076 non-null   float64
# dtypes: float64(1)
# memory usage: 17.1 KB
# None

# %%
class TestStrategy(bt.Strategy):
    def __init__(self):
        self.btc_price = self.data0.Close
        self.eth_price = self.data1.Close
        self.signal = new_df  

    def next(self):
        current_signal = self.signal.loc[self.datetime.datetime()]  # Access the signal for the current date
        print(f"Current Signal: {current_signal}")
        for idx, value in self.signal.iterrows():
            if value['signal'] > 1: 
                self.buy(data=self.data0,size=1)
                self.sell(data=self.data1,size=1)
            # elif value['signal'] < -1: 
            #     self.sell(data=self.data0)
            #     self.buy(data=self.data1)
            elif abs(value['signal']) < 0.3:
                self.close()
    

if __name__ == '__main__':
    cerebro = bt.Cerebro()
    
    btc = bt.feeds.PandasData(dataname = df_btc)
    cerebro.adddata(btc)
    
    eth = bt.feeds.PandasData(dataname = df_eth)
    cerebro.adddata(eth)
    # signals = bt.feeds.PandasData(dataname = new_df)
    # cerebro.adddata(signals)
    
    cerebro.addstrategy(TestStrategy)  # Adding the test strategy
    
    cerebro.addanalyzer(bt.analyzers.Returns)
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, riskfreerate=0.0)
    cerebro.addanalyzer(bt.analyzers.DrawDown)
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer)
    
    results = cerebro.run()
    
    returns = results[0].analyzers.returns.get_analysis()
    sharpe_ratio = results[0].analyzers.sharperatio.get_analysis()
    drawdown_info = results[0].analyzers.drawdown.get_analysis()
    trade_info = results[0].analyzers.tradeanalyzer.get_analysis()

    print("Returns:", returns)
    print("Sharpe Ratio:", sharpe_ratio)
    print("Drawdown Info:", drawdown_info)
    print("Trade Info:", trade_info)
# Out:
# Current Signal: signal   NaN
# Name: 2022-01-03 00:00:00, dtype: float64
# Current Signal: signal   NaN
# Name: 2022-01-04 00:00:00, dtype: float64
# Current Signal: signal   NaN
# Name: 2022-01-05 00:00:00, dtype: float64
# Current Signal: signal   NaN
# Name: 2022-01-06 00:00:00, dtype: float64
# Current Signal: signal   NaN
# Name: 2022-01-07 00:00:00, dtype: float64
# Current Signal: signal   -1.393154
# Name: 2022-01-08 00:00:00, dtype: float64
# Current Signal: signal   -1.283257
# Name: 2022-01-09 00:00:00, dtype: float64
# Current Signal: signal   -1.185018
# Name: 2022-01-10 00:00:00, dtype: float64
# Current Signal: signal   -0.917038
# Name: 2022-01-11 00:00:00, dtype: float64
# Current Signal: signal   -0.585802
# Name: 2022-01-12 00:00:00, dtype: float64
# Current Signal: signal    0.502872
# Name: 2022-01-13 00:00:00, dtype: float64
# Current Signal: signal    0.816032
# Name: 2022-01-14 00:00:00, dtype: float64
# Current Signal: signal    0.838862
# Name: 2022-01-15 00:00:00, dtype: float64
# Current Signal: signal    0.95813
# Name: 2022-01-16 00:00:00, dtype: float64
# Current Signal: signal    0.82547
# Name: 2022-01-17 00:00:00, dtype: float64
# Current Signal: signal   -0.221754
# Name: 2022-01-18 00:00:00, dtype: float64
# Current Signal: signal   -1.338771
# Name: 2022-01-19 00:00:00, dtype: float64
# Current Signal: signal   -1.407358
# Name: 2022-01-20 00:00:00, dtype: float64
# Current Signal: signal   -1.061124
# Name: 2022-01-21 00:00:00, dtype: float64
# Current Signal: signal   -1.280574
# Name: 2022-01-22 00:00:00, dtype: float64
# Current Signal: signal   -1.523346
# Name: 2022-01-23 00:00:00, dtype: float64
# Current Signal: signal   -1.175355
# Name: 2022-01-24 00:00:00, dtype: float64
# Current Signal: signal   -1.137635
# Name: 2022-01-25 00:00:00, dtype: float64
# Current Signal: signal   -1.124339
# Name: 2022-01-26 00:00:00, dtype: float64
# Current Signal: signal   -0.743686
# Name: 2022-01-27 00:00:00, dtype: float64
# Current Signal: signal   -0.814652
# Name: 2022-01-28 00:00:00, dtype: float64
# Current Signal: signal   -0.658618
# Name: 2022-01-29 00:00:00, dtype: float64
# Current Signal: signal    0.678151
# Name: 2022-01-30 00:00:00, dtype: float64
# Current Signal: signal    1.12286
# Name: 2022-01-31 00:00:00, dtype: float64
# Current Signal: signal    1.104605
# Name: 2022-02-01 00:00:00, dtype: float64
# Current Signal: signal    1.373077
# Name: 2022-02-02 00:00:00, dtype: float64
# Current Signal: signal    1.186031
# Name: 2022-02-03 00:00:00, dtype: float64
# Current Signal: signal    1.13349
# Name: 2022-02-04 00:00:00, dtype: float64
# Current Signal: signal    0.984682
# Name: 2022-02-05 00:00:00, dtype: float64
# Current Signal: signal    0.629595
# Name: 2022-02-06 00:00:00, dtype: float64
# Current Signal: signal    0.195106
# Name: 2022-02-07 00:00:00, dtype: float64
# Current Signal: signal   -0.813548
# Name: 2022-02-08 00:00:00, dtype: float64
# Current Signal: signal   -1.227632
# Name: 2022-02-09 00:00:00, dtype: float64
# Current Signal: signal   -0.218385
# Name: 2022-02-10 00:00:00, dtype: float64
# Current Signal: signal   -0.046967
# Name: 2022-02-11 00:00:00, dtype: float64
# Current Signal: signal   -1.050968
# Name: 2022-02-12 00:00:00, dtype: float64
# Current Signal: signal   -1.458283
# Name: 2022-02-13 00:00:00, dtype: float64
# Current Signal: signal   -1.152729
# Name: 2022-02-14 00:00:00, dtype: float64
# Current Signal: signal   -0.823376
# Name: 2022-02-15 00:00:00, dtype: float64
# Current Signal: signal    0.24964
# Name: 2022-02-16 00:00:00, dtype: float64
# Current Signal: signal    1.013886
# Name: 2022-02-17 00:00:00, dtype: float64
# Current Signal: signal    1.108864
# Name: 2022-02-18 00:00:00, dtype: float64
# Current Signal: signal    0.427052
# Name: 2022-02-19 00:00:00, dtype: float64
# Current Signal: signal   -0.761208
# Name: 2022-02-20 00:00:00, dtype: float64
# Current Signal: signal   -1.038121
# Name: 2022-02-21 00:00:00, dtype: float64
# Current Signal: signal   -0.694482
# Name: 2022-02-22 00:00:00, dtype: float64
# Current Signal: signal   -0.411024
# Name: 2022-02-23 00:00:00, dtype: float64
# Current Signal: signal   -0.28803
# Name: 2022-02-24 00:00:00, dtype: float64
# Current Signal: signal   -1.044963
# Name: 2022-02-25 00:00:00, dtype: float64
# Current Signal: signal    0.195059
# Name: 2022-02-26 00:00:00, dtype: float64
# Current Signal: signal    1.182712
# Name: 2022-02-27 00:00:00, dtype: float64
# Current Signal: signal    0.558037
# Name: 2022-02-28 00:00:00, dtype: float64
# Current Signal: signal   -0.685862
# Name: 2022-03-01 00:00:00, dtype: float64
# Current Signal: signal   -1.04459
# Name: 2022-03-02 00:00:00, dtype: float64
# Current Signal: signal   -1.030756
# Name: 2022-03-03 00:00:00, dtype: float64
# Current Signal: signal   -1.000529
# Name: 2022-03-04 00:00:00, dtype: float64
# Current Signal: signal   -0.784038
# Name: 2022-03-05 00:00:00, dtype: float64
# Current Signal: signal    0.054688
# Name: 2022-03-06 00:00:00, dtype: float64
# Current Signal: signal    0.10791
# Name: 2022-03-07 00:00:00, dtype: float64
# Current Signal: signal   -0.828888
# Name: 2022-03-08 00:00:00, dtype: float64
# Current Signal: signal   -1.010271
# Name: 2022-03-09 00:00:00, dtype: float64
# Current Signal: signal   -0.932982
# Name: 2022-03-10 00:00:00, dtype: float64
# Current Signal: signal   -0.510238
# Name: 2022-03-11 00:00:00, dtype: float64
# Current Signal: signal   -0.082791
# Name: 2022-03-12 00:00:00, dtype: float64
# Current Signal: signal    0.119017
# Name: 2022-03-13 00:00:00, dtype: float64
# Current Signal: signal    0.492735
# Name: 2022-03-14 00:00:00, dtype: float64
# Current Signal: signal   -0.022388
# Name: 2022-03-15 00:00:00, dtype: float64
# Current Signal: signal   -0.022788
# Name: 2022-03-16 00:00:00, dtype: float64
# Current Signal: signal    1.290262
# Name: 2022-03-17 00:00:00, dtype: float64
# Current Signal: signal    1.517482
# Name: 2022-03-18 00:00:00, dtype: float64
# Current Signal: signal    1.457384
# Name: 2022-03-19 00:00:00, dtype: float64
# Current Signal: signal    1.220308
# Name: 2022-03-20 00:00:00, dtype: float64
# Current Signal: signal    0.692658
# Name: 2022-03-21 00:00:00, dtype: float64
# Current Signal: signal    0.83322
# Name: 2022-03-22 00:00:00, dtype: float64
# Current Signal: signal    0.563478
# Name: 2022-03-23 00:00:00, dtype: float64
# Current Signal: signal    0.385326
# Name: 2022-03-24 00:00:00, dtype: float64
# Current Signal: signal    0.596227
# Name: 2022-03-25 00:00:00, dtype: float64
# Current Signal: signal    0.222775
# Name: 2022-03-26 00:00:00, dtype: float64
# Current Signal: signal   -0.276002
# Name: 2022-03-27 00:00:00, dtype: float64
# Current Signal: signal   -0.00003
# Name: 2022-03-28 00:00:00, dtype: float64
# Current Signal: signal    0.487375
# Name: 2022-03-29 00:00:00, dtype: float64
# Current Signal: signal    1.334633
# Name: 2022-03-30 00:00:00, dtype: float64
# Current Signal: signal    1.331361
# Name: 2022-03-31 00:00:00, dtype: float64
# Current Signal: signal    1.221462
# Name: 2022-04-01 00:00:00, dtype: float64
# Current Signal: signal    1.354125
# Name: 2022-04-02 00:00:00, dtype: float64
# Current Signal: signal    1.484462
# Name: 2022-04-03 00:00:00, dtype: float64
# Current Signal: signal    1.282316
# Name: 2022-04-04 00:00:00, dtype: float64
# Current Signal: signal    1.016714
# Name: 2022-04-05 00:00:00, dtype: float64
# Current Signal: signal    0.5078
# Name: 2022-04-06 00:00:00, dtype: float64
# Current Signal: signal   -0.563611
# Name: 2022-04-07 00:00:00, dtype: float64
# Current Signal: signal   -0.91895
# Name: 2022-04-08 00:00:00, dtype: float64
# Current Signal: signal    0.255244
# Name: 2022-04-09 00:00:00, dtype: float64
# Current Signal: signal    0.941086
# Name: 2022-04-10 00:00:00, dtype: float64
# Current Signal: signal    0.935613
# Name: 2022-04-11 00:00:00, dtype: float64
# Current Signal: signal    0.184367
# Name: 2022-04-12 00:00:00, dtype: float64
# Current Signal: signal    0.436576
# Name: 2022-04-13 00:00:00, dtype: float64
# Current Signal: signal    0.188985
# Name: 2022-04-14 00:00:00, dtype: float64
# Current Signal: signal   -0.061468
# Name: 2022-04-15 00:00:00, dtype: float64
# Current Signal: signal   -0.494554
# Name: 2022-04-16 00:00:00, dtype: float64
# Current Signal: signal   -0.130828
# Name: 2022-04-17 00:00:00, dtype: float64
# Current Signal: signal   -0.115394
# Name: 2022-04-18 00:00:00, dtype: float64
# Current Signal: signal   -1.171657
# Name: 2022-04-19 00:00:00, dtype: float64
# Current Signal: signal   -0.708734
# Name: 2022-04-20 00:00:00, dtype: float64
# Current Signal: signal   -0.940832
# Name: 2022-04-21 00:00:00, dtype: float64
# Current Signal: signal   -1.169359
# Name: 2022-04-22 00:00:00, dtype: float64
# Current Signal: signal   -0.469553
# Name: 2022-04-23 00:00:00, dtype: float64
# Current Signal: signal   -0.007724
# Name: 2022-04-24 00:00:00, dtype: float64
# Current Signal: signal   -0.785888
# Name: 2022-04-25 00:00:00, dtype: float64
# Current Signal: signal   -0.905514
# Name: 2022-04-26 00:00:00, dtype: float64
# Current Signal: signal   -0.248544
# Name: 2022-04-27 00:00:00, dtype: float64
# Current Signal: signal   -0.855918
# Name: 2022-04-28 00:00:00, dtype: float64
# Current Signal: signal   -0.676655
# Name: 2022-04-29 00:00:00, dtype: float64
# Current Signal: signal   -0.725519
# Name: 2022-04-30 00:00:00, dtype: float64
# Current Signal: signal   -1.224985
# Name: 2022-05-01 00:00:00, dtype: float64
# Current Signal: signal   -1.033137
# Name: 2022-05-02 00:00:00, dtype: float64
# Current Signal: signal    0.305515
# Name: 2022-05-03 00:00:00, dtype: float64
# Current Signal: signal    0.770465
# Name: 2022-05-04 00:00:00, dtype: float64
# Current Signal: signal    0.438178
# Name: 2022-05-05 00:00:00, dtype: float64
# Current Signal: signal    1.338538
# Name: 2022-05-06 00:00:00, dtype: float64
# Current Signal: signal    1.294363
# Name: 2022-05-07 00:00:00, dtype: float64
# Current Signal: signal    0.601923
# Name: 2022-05-08 00:00:00, dtype: float64
# Current Signal: signal   -0.565389
# Name: 2022-05-09 00:00:00, dtype: float64
# Current Signal: signal   -0.237416
# Name: 2022-05-10 00:00:00, dtype: float64
# Current Signal: signal    0.925179
# Name: 2022-05-11 00:00:00, dtype: float64
# Current Signal: signal   -0.690341
# Name: 2022-05-12 00:00:00, dtype: float64
# Current Signal: signal   -1.553372
# Name: 2022-05-13 00:00:00, dtype: float64
# Current Signal: signal   -1.205885
# Name: 2022-05-14 00:00:00, dtype: float64
# Current Signal: signal   -0.857162
# Name: 2022-05-15 00:00:00, dtype: float64
# Current Signal: signal   -0.661029
# Name: 2022-05-16 00:00:00, dtype: float64
# Current Signal: signal   -0.533021
# Name: 2022-05-17 00:00:00, dtype: float64
# Current Signal: signal   -0.252412
# Name: 2022-05-18 00:00:00, dtype: float64
# Current Signal: signal   -0.8391
# Name: 2022-05-19 00:00:00, dtype: float64
# Current Signal: signal   -1.492698
# Name: 2022-05-20 00:00:00, dtype: float64
# Current Signal: signal   -0.889947
# Name: 2022-05-21 00:00:00, dtype: float64
# Current Signal: signal   -0.558003
# Name: 2022-05-22 00:00:00, dtype: float64
# Current Signal: signal   -0.078027
# Name: 2022-05-23 00:00:00, dtype: float64
# Current Signal: signal    0.726242
# Name: 2022-05-24 00:00:00, dtype: float64
# Current Signal: signal   -0.104912
# Name: 2022-05-25 00:00:00, dtype: float64
# Current Signal: signal   -1.259411
# Name: 2022-05-26 00:00:00, dtype: float64
# Current Signal: signal   -1.445447
# Name: 2022-05-27 00:00:00, dtype: float64
# Current Signal: signal   -1.55202
# Name: 2022-05-28 00:00:00, dtype: float64
# Current Signal: signal   -1.079805
# Name: 2022-05-29 00:00:00, dtype: float64
# Current Signal: signal   -0.699484
# Name: 2022-05-30 00:00:00, dtype: float64
# Current Signal: signal   -0.247945
# Name: 2022-05-31 00:00:00, dtype: float64
# Current Signal: signal   -0.088197
# Name: 2022-06-01 00:00:00, dtype: float64
# Current Signal: signal   -0.672471
# Name: 2022-06-02 00:00:00, dtype: float64
# Current Signal: signal   -1.145704
# Name: 2022-06-03 00:00:00, dtype: float64
# Current Signal: signal   -1.32503
# Name: 2022-06-04 00:00:00, dtype: float64
# Current Signal: signal   -0.927577
# Name: 2022-06-05 00:00:00, dtype: float64
# Current Signal: signal   -0.293934
# Name: 2022-06-06 00:00:00, dtype: float64
# Current Signal: signal   -0.528465
# Name: 2022-06-07 00:00:00, dtype: float64
# Current Signal: signal   -1.147026
# Name: 2022-06-08 00:00:00, dtype: float64
# Current Signal: signal   -1.080099
# Name: 2022-06-09 00:00:00, dtype: float64
# Current Signal: signal   -0.465195
# Name: 2022-06-10 00:00:00, dtype: float64
# Current Signal: signal   -1.038038
# Name: 2022-06-11 00:00:00, dtype: float64
# Current Signal: signal   -1.510157
# Name: 2022-06-12 00:00:00, dtype: float64
# Current Signal: signal   -1.408021
# Name: 2022-06-13 00:00:00, dtype: float64
# Current Signal: signal   -1.08867
# Name: 2022-06-14 00:00:00, dtype: float64
# Current Signal: signal   -0.580999
# Name: 2022-06-15 00:00:00, dtype: float64
# Current Signal: signal   -0.522285
# Name: 2022-06-16 00:00:00, dtype: float64
# Current Signal: signal   -0.45718
# Name: 2022-06-17 00:00:00, dtype: float64
# Current Signal: signal   -0.873134
# Name: 2022-06-18 00:00:00, dtype: float64
# Current Signal: signal   -0.655651
# Name: 2022-06-19 00:00:00, dtype: float64
# Current Signal: signal    0.168348
# Name: 2022-06-20 00:00:00, dtype: float64
# Current Signal: signal    1.08728
# Name: 2022-06-21 00:00:00, dtype: float64
# Current Signal: signal    0.840442
# Name: 2022-06-22 00:00:00, dtype: float64
# Current Signal: signal    0.082613
# Name: 2022-06-23 00:00:00, dtype: float64
# Current Signal: signal    0.102654
# Name: 2022-06-24 00:00:00, dtype: float64
# Current Signal: signal    1.238736
# Name: 2022-06-25 00:00:00, dtype: float64
# Current Signal: signal    1.389453
# Name: 2022-06-26 00:00:00, dtype: float64
# Current Signal: signal    1.079223
# Name: 2022-06-27 00:00:00, dtype: float64
# Current Signal: signal    0.754226
# Name: 2022-06-28 00:00:00, dtype: float64
# Current Signal: signal    0.421467
# Name: 2022-06-29 00:00:00, dtype: float64
# Current Signal: signal   -0.965553
# Name: 2022-06-30 00:00:00, dtype: float64
# Current Signal: signal   -1.521132
# Name: 2022-07-01 00:00:00, dtype: float64
# Current Signal: signal   -1.051168
# Name: 2022-07-02 00:00:00, dtype: float64
# Current Signal: signal   -0.487802
# Name: 2022-07-03 00:00:00, dtype: float64
# Current Signal: signal   -0.03942
# Name: 2022-07-04 00:00:00, dtype: float64
# Current Signal: signal    0.951562
# Name: 2022-07-05 00:00:00, dtype: float64
# Current Signal: signal    1.310234
# Name: 2022-07-06 00:00:00, dtype: float64
# Current Signal: signal    1.014418
# Name: 2022-07-07 00:00:00, dtype: float64
# Current Signal: signal    1.247947
# Name: 2022-07-08 00:00:00, dtype: float64
# Current Signal: signal    0.227835
# Name: 2022-07-09 00:00:00, dtype: float64
# Current Signal: signal   -0.381629
# Name: 2022-07-10 00:00:00, dtype: float64
# Current Signal: signal   -0.911843
# Name: 2022-07-11 00:00:00, dtype: float64
# Current Signal: signal   -1.002278
# Name: 2022-07-12 00:00:00, dtype: float64
# Current Signal: signal   -1.388435
# Name: 2022-07-13 00:00:00, dtype: float64
# Current Signal: signal   -1.02667
# Name: 2022-07-14 00:00:00, dtype: float64
# Current Signal: signal    0.657998
# Name: 2022-07-15 00:00:00, dtype: float64
# Current Signal: signal    1.499461
# Name: 2022-07-16 00:00:00, dtype: float64
# Current Signal: signal    1.363008
# Name: 2022-07-17 00:00:00, dtype: float64
# Current Signal: signal    1.468389
# Name: 2022-07-18 00:00:00, dtype: float64
# Current Signal: signal    1.3253
# Name: 2022-07-19 00:00:00, dtype: float64
# Current Signal: signal    1.113364
# Name: 2022-07-20 00:00:00, dtype: float64
# Current Signal: signal    0.471138
# Name: 2022-07-21 00:00:00, dtype: float64
# Current Signal: signal    0.513397
# Name: 2022-07-22 00:00:00, dtype: float64
# Current Signal: signal    0.893419
# Name: 2022-07-23 00:00:00, dtype: float64
# Current Signal: signal    0.869405
# Name: 2022-07-24 00:00:00, dtype: float64
# Current Signal: signal    1.027177
# Name: 2022-07-25 00:00:00, dtype: float64
# Current Signal: signal    0.47601
# Name: 2022-07-26 00:00:00, dtype: float64
# Current Signal: signal   -0.474978
# Name: 2022-07-27 00:00:00, dtype: float64
# Current Signal: signal    0.439567
# Name: 2022-07-28 00:00:00, dtype: float64
# Current Signal: signal    1.216344
# Name: 2022-07-29 00:00:00, dtype: float64
# Current Signal: signal    1.004779
# Name: 2022-07-30 00:00:00, dtype: float64
# Current Signal: signal    0.730196
# Name: 2022-07-31 00:00:00, dtype: float64
# Current Signal: signal    0.67964
# Name: 2022-08-01 00:00:00, dtype: float64
# Current Signal: signal    0.045035
# Name: 2022-08-02 00:00:00, dtype: float64
# Current Signal: signal   -1.194669
# Name: 2022-08-03 00:00:00, dtype: float64
# Current Signal: signal   -0.619087
# Name: 2022-08-04 00:00:00, dtype: float64
# Current Signal: signal   -0.323657
# Name: 2022-08-05 00:00:00, dtype: float64
# Current Signal: signal    1.028872
# Name: 2022-08-06 00:00:00, dtype: float64
# Current Signal: signal    1.431869
# Name: 2022-08-07 00:00:00, dtype: float64
# Current Signal: signal    0.876625
# Name: 2022-08-08 00:00:00, dtype: float64
# Current Signal: signal    0.80707
# Name: 2022-08-09 00:00:00, dtype: float64
# Current Signal: signal    0.629968
# Name: 2022-08-10 00:00:00, dtype: float64
# Current Signal: signal    1.027041
# Name: 2022-08-11 00:00:00, dtype: float64
# Current Signal: signal    1.508392
# Name: 2022-08-12 00:00:00, dtype: float64
# Current Signal: signal    1.392128
# Name: 2022-08-13 00:00:00, dtype: float64
# Current Signal: signal    1.294056
# Name: 2022-08-14 00:00:00, dtype: float64
# Current Signal: signal    0.862443
# Name: 2022-08-15 00:00:00, dtype: float64
# Current Signal: signal    0.154097
# Name: 2022-08-16 00:00:00, dtype: float64
# Current Signal: signal   -0.365834
# Name: 2022-08-17 00:00:00, dtype: float64
# Current Signal: signal   -0.696059
# Name: 2022-08-18 00:00:00, dtype: float64
# Current Signal: signal   -0.321015
# Name: 2022-08-19 00:00:00, dtype: float64
# Current Signal: signal   -0.553145
# Name: 2022-08-20 00:00:00, dtype: float64
# Current Signal: signal   -1.455201
# Name: 2022-08-21 00:00:00, dtype: float64
# Current Signal: signal   -1.507949
# Name: 2022-08-22 00:00:00, dtype: float64
# Current Signal: signal   -1.085892
# Name: 2022-08-23 00:00:00, dtype: float64
# Current Signal: signal   -0.291576
# Name: 2022-08-24 00:00:00, dtype: float64
# Current Signal: signal    0.498162
# Name: 2022-08-25 00:00:00, dtype: float64
# Current Signal: signal    1.128182
# Name: 2022-08-26 00:00:00, dtype: float64
# Current Signal: signal    0.081617
# Name: 2022-08-27 00:00:00, dtype: float64
# Current Signal: signal   -1.029239
# Name: 2022-08-28 00:00:00, dtype: float64
# Current Signal: signal   -1.081378
# Name: 2022-08-29 00:00:00, dtype: float64
# Current Signal: signal   -0.489006
# Name: 2022-08-30 00:00:00, dtype: float64
# Current Signal: signal    0.63384
# Name: 2022-08-31 00:00:00, dtype: float64
# Current Signal: signal    0.884272
# Name: 2022-09-01 00:00:00, dtype: float64
# Current Signal: signal    1.043049
# Name: 2022-09-02 00:00:00, dtype: float64
# Current Signal: signal    1.074799
# Name: 2022-09-03 00:00:00, dtype: float64
# Current Signal: signal    0.559297
# Name: 2022-09-04 00:00:00, dtype: float64
# Current Signal: signal    0.639569
# Name: 2022-09-05 00:00:00, dtype: float64
# Current Signal: signal    1.158222
# Name: 2022-09-06 00:00:00, dtype: float64
# Current Signal: signal    1.455839
# Name: 2022-09-07 00:00:00, dtype: float64
# Current Signal: signal    1.016753
# Name: 2022-09-08 00:00:00, dtype: float64
# Current Signal: signal    1.153245
# Name: 2022-09-09 00:00:00, dtype: float64
# Current Signal: signal    0.095472
# Name: 2022-09-10 00:00:00, dtype: float64
# Current Signal: signal   -0.534827
# Name: 2022-09-11 00:00:00, dtype: float64
# Current Signal: signal   -0.66836
# Name: 2022-09-12 00:00:00, dtype: float64
# Current Signal: signal   -1.26612
# Name: 2022-09-13 00:00:00, dtype: float64
# Current Signal: signal   -1.167077
# Name: 2022-09-14 00:00:00, dtype: float64
# Current Signal: signal   -0.142625
# Name: 2022-09-15 00:00:00, dtype: float64
# Current Signal: signal   -0.618653
# Name: 2022-09-16 00:00:00, dtype: float64
# Current Signal: signal   -1.329658
# Name: 2022-09-17 00:00:00, dtype: float64
# Current Signal: signal   -1.252963
# Name: 2022-09-18 00:00:00, dtype: float64
# Current Signal: signal   -1.079367
# Name: 2022-09-19 00:00:00, dtype: float64
# Current Signal: signal   -1.067256
# Name: 2022-09-20 00:00:00, dtype: float64
# Current Signal: signal   -0.702652
# Name: 2022-09-21 00:00:00, dtype: float64
# Current Signal: signal   -1.037952
# Name: 2022-09-22 00:00:00, dtype: float64
# Current Signal: signal   -1.309042
# Name: 2022-09-23 00:00:00, dtype: float64
# Current Signal: signal   -0.483491
# Name: 2022-09-24 00:00:00, dtype: float64
# Current Signal: signal    0.120126
# Name: 2022-09-25 00:00:00, dtype: float64
# Current Signal: signal   -0.111155
# Name: 2022-09-26 00:00:00, dtype: float64
# Current Signal: signal   -0.11709
# Name: 2022-09-27 00:00:00, dtype: float64
# Current Signal: signal    0.09241
# Name: 2022-09-28 00:00:00, dtype: float64
# Current Signal: signal   -0.576444
# Name: 2022-09-29 00:00:00, dtype: float64
# Current Signal: signal   -0.764333
# Name: 2022-09-30 00:00:00, dtype: float64
# Current Signal: signal   -0.717476
# Name: 2022-10-01 00:00:00, dtype: float64
# Current Signal: signal   -0.661959
# Name: 2022-10-02 00:00:00, dtype: float64
# Current Signal: signal   -1.291847
# Name: 2022-10-03 00:00:00, dtype: float64
# Current Signal: signal   -1.128791
# Name: 2022-10-04 00:00:00, dtype: float64
# Current Signal: signal   -1.080868
# Name: 2022-10-05 00:00:00, dtype: float64
# Current Signal: signal   -1.068668
# Name: 2022-10-06 00:00:00, dtype: float64
# Current Signal: signal    0.112513
# Name: 2022-10-07 00:00:00, dtype: float64
# Current Signal: signal    0.922143
# Name: 2022-10-08 00:00:00, dtype: float64
# Current Signal: signal    0.743312
# Name: 2022-10-09 00:00:00, dtype: float64
# Current Signal: signal    0.4222
# Name: 2022-10-10 00:00:00, dtype: float64
# Current Signal: signal    0.068516
# Name: 2022-10-11 00:00:00, dtype: float64
# Current Signal: signal   -1.040954
# Name: 2022-10-12 00:00:00, dtype: float64
# Current Signal: signal   -0.83215
# Name: 2022-10-13 00:00:00, dtype: float64
# Current Signal: signal   -1.189998
# Name: 2022-10-14 00:00:00, dtype: float64
# Current Signal: signal   -0.402335
# Name: 2022-10-15 00:00:00, dtype: float64
# Current Signal: signal   -0.252083
# Name: 2022-10-16 00:00:00, dtype: float64
# Current Signal: signal    0.074516
# Name: 2022-10-17 00:00:00, dtype: float64
# Current Signal: signal    1.08042
# Name: 2022-10-18 00:00:00, dtype: float64
# Current Signal: signal    0.734312
# Name: 2022-10-19 00:00:00, dtype: float64
# Current Signal: signal    0.161715
# Name: 2022-10-20 00:00:00, dtype: float64
# Current Signal: signal   -0.402799
# Name: 2022-10-21 00:00:00, dtype: float64
# Current Signal: signal    0.111197
# Name: 2022-10-22 00:00:00, dtype: float64
# Current Signal: signal    1.036048
# Name: 2022-10-23 00:00:00, dtype: float64
# Current Signal: signal    1.332727
# Name: 2022-10-24 00:00:00, dtype: float64
# Current Signal: signal    1.523097
# Name: 2022-10-25 00:00:00, dtype: float64
# Current Signal: signal    1.333123
# Name: 2022-10-26 00:00:00, dtype: float64
# Current Signal: signal    1.562243
# Name: 2022-10-27 00:00:00, dtype: float64
# Current Signal: signal    1.234807
# Name: 2022-10-28 00:00:00, dtype: float64
# Current Signal: signal    0.945873
# Name: 2022-10-29 00:00:00, dtype: float64
# Current Signal: signal    1.116811
# Name: 2022-10-30 00:00:00, dtype: float64
# Current Signal: signal    0.965249
# Name: 2022-10-31 00:00:00, dtype: float64
# Current Signal: signal    0.727418
# Name: 2022-11-01 00:00:00, dtype: float64
# Current Signal: signal    0.425015
# Name: 2022-11-02 00:00:00, dtype: float64
# Current Signal: signal   -0.238737
# Name: 2022-11-03 00:00:00, dtype: float64
# Current Signal: signal   -0.93706
# Name: 2022-11-04 00:00:00, dtype: float64
# Current Signal: signal    0.309346
# Name: 2022-11-05 00:00:00, dtype: float64
# Current Signal: signal    0.270798
# Name: 2022-11-06 00:00:00, dtype: float64
# Current Signal: signal   -0.781978
# Name: 2022-11-07 00:00:00, dtype: float64
# Current Signal: signal   -0.896566
# Name: 2022-11-08 00:00:00, dtype: float64
# Current Signal: signal   -1.10217
# Name: 2022-11-09 00:00:00, dtype: float64
# Current Signal: signal   -1.573382
# Name: 2022-11-10 00:00:00, dtype: float64
# Current Signal: signal   -0.617958
# Name: 2022-11-11 00:00:00, dtype: float64
# Current Signal: signal    0.195171
# Name: 2022-11-12 00:00:00, dtype: float64
# Current Signal: signal    0.522875
# Name: 2022-11-13 00:00:00, dtype: float64
# Current Signal: signal    0.427215
# Name: 2022-11-14 00:00:00, dtype: float64
# Current Signal: signal    0.590969
# Name: 2022-11-15 00:00:00, dtype: float64
# Current Signal: signal    0.19224
# Name: 2022-11-16 00:00:00, dtype: float64
# Current Signal: signal   -1.238451
# Name: 2022-11-17 00:00:00, dtype: float64
# Current Signal: signal   -1.415425
# Name: 2022-11-18 00:00:00, dtype: float64
# Current Signal: signal   -1.066695
# Name: 2022-11-19 00:00:00, dtype: float64
# Current Signal: signal   -0.596709
# Name: 2022-11-20 00:00:00, dtype: float64
# Current Signal: signal   -0.975937
# Name: 2022-11-21 00:00:00, dtype: float64
# Current Signal: signal   -1.476402
# Name: 2022-11-22 00:00:00, dtype: float64
# Current Signal: signal   -1.141973
# Name: 2022-11-23 00:00:00, dtype: float64
# Current Signal: signal   -0.236216
# Name: 2022-11-24 00:00:00, dtype: float64
# Current Signal: signal    0.653446
# Name: 2022-11-25 00:00:00, dtype: float64
# Current Signal: signal    0.945105
# Name: 2022-11-26 00:00:00, dtype: float64
# Current Signal: signal    1.240523
# Name: 2022-11-27 00:00:00, dtype: float64
# Current Signal: signal    0.849819
# Name: 2022-11-28 00:00:00, dtype: float64
# Current Signal: signal    0.175927
# Name: 2022-11-29 00:00:00, dtype: float64
# Current Signal: signal    0.859824
# Name: 2022-11-30 00:00:00, dtype: float64
# Current Signal: signal    1.421948
# Name: 2022-12-01 00:00:00, dtype: float64
# Current Signal: signal    1.149804
# Name: 2022-12-02 00:00:00, dtype: float64
# Current Signal: signal    0.981467
# Name: 2022-12-03 00:00:00, dtype: float64
# Current Signal: signal    0.335504
# Name: 2022-12-04 00:00:00, dtype: float64
# Current Signal: signal   -0.387186
# Name: 2022-12-05 00:00:00, dtype: float64
# Current Signal: signal   -0.500376
# Name: 2022-12-06 00:00:00, dtype: float64
# Current Signal: signal   -0.915388
# Name: 2022-12-07 00:00:00, dtype: float64
# Current Signal: signal   -1.070284
# Name: 2022-12-08 00:00:00, dtype: float64
# Current Signal: signal   -0.467895
# Name: 2022-12-09 00:00:00, dtype: float64
# Current Signal: signal    0.326849
# Name: 2022-12-10 00:00:00, dtype: float64
# Current Signal: signal   -0.034745
# Name: 2022-12-11 00:00:00, dtype: float64
# Current Signal: signal    0.217503
# Name: 2022-12-12 00:00:00, dtype: float64
# Current Signal: signal   -0.17428
# Name: 2022-12-13 00:00:00, dtype: float64
# Current Signal: signal    0.55529
# Name: 2022-12-14 00:00:00, dtype: float64
# Current Signal: signal   -0.496069
# Name: 2022-12-15 00:00:00, dtype: float64
# Current Signal: signal   -1.420854
# Name: 2022-12-16 00:00:00, dtype: float64
# Current Signal: signal   -1.352269
# Name: 2022-12-17 00:00:00, dtype: float64
# Current Signal: signal   -1.434553
# Name: 2022-12-18 00:00:00, dtype: float64
# Current Signal: signal   -1.013487
# Name: 2022-12-19 00:00:00, dtype: float64
# Current Signal: signal   -0.599725
# Name: 2022-12-20 00:00:00, dtype: float64
# Current Signal: signal    0.265374
# Name: 2022-12-21 00:00:00, dtype: float64
# Current Signal: signal    0.810236
# Name: 2022-12-22 00:00:00, dtype: float64
# Current Signal: signal    0.970687
# Name: 2022-12-23 00:00:00, dtype: float64
# Current Signal: signal    1.0849
# Name: 2022-12-24 00:00:00, dtype: float64
# Current Signal: signal    0.856696
# Name: 2022-12-25 00:00:00, dtype: float64
# Current Signal: signal    0.538351
# Name: 2022-12-26 00:00:00, dtype: float64
# Current Signal: signal    0.492862
# Name: 2022-12-27 00:00:00, dtype: float64
# Current Signal: signal   -0.066981
# Name: 2022-12-28 00:00:00, dtype: float64
# Current Signal: signal   -1.115635
# Name: 2022-12-29 00:00:00, dtype: float64
# Current Signal: signal   -0.553219
# Name: 2022-12-30 00:00:00, dtype: float64
# Current Signal: signal   -0.140179
# Name: 2022-12-31 00:00:00, dtype: float64
# Returns: OrderedDict([('rtot', 13.24678942461431), ('ravg', 0.0362925737660666), ('rnorm', 9373.313195878916), ('rnorm100', 937331.3195878917)])
# Sharpe Ratio: OrderedDict([('sharperatio', None)])
# Drawdown Info: AutoOrderedDict([('len', 53), ('drawdown', 30.765552410079774), ('moneydown', 2516228262.698929), ('max', AutoOrderedDict([('len', 53), ('drawdown', 246.8244267224875), ('moneydown', 3937413948.2070465)]))])
# Trade Info: AutoOrderedDict([('total', AutoOrderedDict([('total', 201), ('open', 2), ('closed', 199)])), ('streak', AutoOrderedDict([('won', AutoOrderedDict([('current', 0), ('longest', 6)])), ('lost', AutoOrderedDict([('current', 3), ('longest', 8)]))])), ('pnl', AutoOrderedDict([('gross', AutoOrderedDict([('total', 5628354157.242158), ('average', 28283186.719809838)])), ('net', AutoOrderedDict([('total', 5628354157.242158), ('average', 28283186.719809838)]))])), ('won', AutoOrderedDict([('total', 100), ('pnl', AutoOrderedDict([('total', 12439927011.892836), ('average', 124399270.11892836), ('max', 1757283435.2098446)]))])), ('lost', AutoOrderedDict([('total', 99), ('pnl', AutoOrderedDict([('total', -6811572854.650678), ('average', -68803766.2085927), ('max', -3606271296.165725)]))])), ('long', AutoOrderedDict([('total', 100), ('pnl', AutoOrderedDict([('total', -2679171.5938949585), ('average', -26791.715938949586), ('won', AutoOrderedDict([('total', 43549010.770477295), ('average', 1036881.208820888), ('max', 14009039.04132843)])), ('lost', AutoOrderedDict([('total', -46228182.36437225), ('average', -797037.6269719354), ('max', -8623537.842559814)]))])), ('won', 42), ('lost', 58)])), ('short', AutoOrderedDict([('total', 99), ('pnl', AutoOrderedDict([('total', 5631033328.836053), ('average', 56879124.5336975), ('won', AutoOrderedDict([('total', 12396378001.122358), ('average', 213730655.1917648), ('max', 1757283435.2098446)])), ('lost', AutoOrderedDict([('total', -6765344672.286305), ('average', -165008406.6411294), ('max', -3606271296.165725)]))])), ('won', 58), ('lost', 41)])), ('len', AutoOrderedDict([('total', 199), ('average', 1.0), ('max', 1), ('min', 1), ('won', AutoOrderedDict([('total', 100), ('average', 1.0), ('max', 1), ('min', 1)])), ('lost', AutoOrderedDict([('total', 99), ('average', 1.0), ('max', 1), ('min', 1)])), ('long', AutoOrderedDict([('total', 100), ('average', 1.0), ('max', 1), ('min', 1), ('won', AutoOrderedDict([('total', 42), ('average', 1.0), ('max', 1), ('min', 1)])), ('lost', AutoOrderedDict([('total', 58), ('average', 1.0), ('max', 1), ('min', 1)]))])), ('short', AutoOrderedDict([('total', 99), ('average', 1.0), ('max', 1), ('min', 1), ('won', AutoOrderedDict([('total', 58), ('average', 1.0), ('max', 1), ('min', 1)])), ('lost', AutoOrderedDict([('total', 41), ('average', 1.0), ('max', 1), ('min', 1)]))]))]))])

# %%
final_portfolio_value = cerebro.broker.getvalue()
print(f"Final portfolio value: {final_portfolio_value}")
print(results)
# Out:
# Final portfolio value: 5662491329.784424
# [<__main__.TestStrategy object at 0x7fae8a6f2860>]
